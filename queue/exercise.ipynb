# %%
#EXCERCISE 1

# %%
# For all exercises use Queue class implemented in main tutorial.

# Design a food ordering system where your python program will run two threads,

# Place Order: This thread will be placing an order and inserting that into a queue. This thread places new order every 0.5 second.
#  (hint: use time.sleep(0.5) function)
# Serve Order: This thread will server the order. All you need to do is pop the order out of the queue and print it. 
# This thread serves an order every 2 seconds. Also start this thread 1 second after place order thread is started.
# Use this video to get yourself familiar with multithreading in python

# Pass following list as an argument to place order thread,

# orders = ['pizza','samosa','pasta','biryani','burger']
# This problem is a producer,consumer problem where place_order thread is producing orders whereas server_order thread is consuming 
# the food orders. Use Queue class implemented in a video tutorial.
from collections import deque
import time
import threading
class Queue:
    def __init__(self):
        self.buffer= deque()
        # print(self.buffer)
    def enqueue(self,value):
        self.buffer.appendleft(value)
         
    def dequeue(self):
        if len(self.buffer)==0:
            print("Emptly Queue")
            return
      
        return self.buffer.pop()
    def length(self):
        return len(self.buffer)
    def isempty(self):
        return len(self.buffer)==0
    def front(self):
        return self.buffer[-1]
    
order_queue=Queue()
def place_order(value):
    for i in value:
        print("Ordering ",i)
        order_queue.enqueue(i)
        time.sleep(0.5)
def serve_order():
    time.sleep(1)

    while True:
        print("Serving Order ")
        print(order_queue.dequeue())
        time.sleep(2)
        if order_queue.isempty():
            print("Order Queue is Empty now")
            break

# %%
q=Queue()
q.enqueue(10)
q.enqueue(12)
q.enqueue(13)
q.enqueue(14)
print(q.front())
print(q.buffer)
# Out:
# 10
# deque([14, 13, 12, 10])

# %%
orders = ['pizza','samosa','pasta','biryani','burger']
place_order=threading.Thread(target=place_order,args=(orders,))

try:
    serve_order=threading.Thread(target=serve_order,args=())
except Exception as e:
    print("Exception Occured while Serving the orders ",e)
place_order.start()
serve_order.start()

place_order.join()
serve_order.join()
# Out:
# Ordering  pizza
# Ordering  samosa
# Ordering Serving Order
# pizza
#  pasta
# Ordering  biryani
# Ordering  burger
# Serving Order
# samosa
# Serving Order
# pasta
# Serving Order
# biryani
# Serving Order
# burger
# Order Queue is Empty now

# %%
# Write a program to print binary numbers from 1 to 10 using Queue. Use Queue class implemented in main tutorial.
#  Binary sequence should look like,
#     1
#     10
#     11
#     100
#     101
#     110
#     111
#     1000
#     1001
#     1010
# Hint: Notice a pattern above. After 1 second and third number is 1+0 and 1+1. 4th and 5th number are second number (i.e. 10) + 0 and second number (i.e. 10) + 1.
binary_queue=Queue()
def printing():
    x=''
    while True:
        if binary_queue.isempty():
            binary_queue.enqueue('1')
            x=binary_queue.dequeue()
        binary_queue.enqueue(x+'0')
        binary_queue.enqueue(x+'1')
        x=binary_queue.dequeue()
        print(x)
        if x=='1010':
            break
        
printing()
# You also need to add front() function in queue class that can return the front element in the queue.
# Out:
# 10
# 11
# 100
# 101
# 110
# 111
# 1000
# 1001
# 1010
